# %% [markdown]
# # scratch notebook for the workshop - ignore

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv')
# Out:
# /tmp/ipykernel_11818/3738925007.py:1: DtypeWarning: Columns (3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv')

# %%
us = df.loc[df.country_region == 'United States']

# %%
us.date = pd.to_datetime(us.date)

# narrow to April 10 2020 and April 24 2020

us = us.loc[(us.date >= '2020-04-09') & (us.date <= '2020-04-24')]
# Out:
# /tmp/ipykernel_11818/2388148759.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us.date = pd.to_datetime(us.date)

# %%
us.rename(columns={'sub_region_1':'state', 'sub_region_2': 'county'}, inplace=True)

# %%
cols_to_keep = ['state','county', 'date', 'retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline']

us = us[cols_to_keep]

# %%
us = us.loc[(us.state.notna()) & (us.county.notna())]

# %%
# create a column that averages all the mobility data
us['all_mobility'] = us.iloc[:,3:9].sum(axis=1)

# %%
us
# Out:
#             state          county       date  \
# 9106474   Alabama  Autauga County 2020-04-09
# 9106475   Alabama  Autauga County 2020-04-10
# 9106476   Alabama  Autauga County 2020-04-11
# 9106477   Alabama  Autauga County 2020-04-12
# 9106478   Alabama  Autauga County 2020-04-13
# ...           ...             ...        ...
# 11615837  Wyoming   Weston County 2020-04-20
# 11615838  Wyoming   Weston County 2020-04-21
# 11615839  Wyoming   Weston County 2020-04-22
# 11615840  Wyoming   Weston County 2020-04-23
# 11615841  Wyoming   Weston County 2020-04-24
#
#           retail_and_recreation_percent_change_from_baseline  \
# 9106474                                               -29.0
# 9106475                                               -30.0
# 9106476                                               -37.0
# 9106477                                               -55.0
# 9106478                                               -22.0
# ...

# %%
us.to_csv('../data/us_mobility.csv', index=False)

# %%
pd.read_csv("../data/google_mobility_data.csv")
# Out:
#        county        date state_name  retail_and_recreation_mobility  \
# 0        1001  2020-04-07    Alabama                             -35
# 1        1001  2020-04-08    Alabama                             -31
# 2        1001  2020-04-09    Alabama                             -29
# 3        1001  2020-04-10    Alabama                             -30
# 4        1001  2020-04-11    Alabama                             -37
# ...       ...         ...        ...                             ...
# 21921   55141  2020-04-23  Wisconsin                             -30
# 21922   55141  2020-04-24  Wisconsin                             -31
# 21923   55141  2020-04-25  Wisconsin                             -25
# 21924   55141  2020-04-26  Wisconsin                             -11
# 21925   55141  2020-04-27  Wisconsin                             -25
#
#        grocery_and_pharmacy_mobility  parks_mobility  transit_mobility  \
# ...

# %%
df = pd.read_csv("../data/google_mobility_data.csv")
df.date = pd.to_datetime(df.date)
df
# Out:
#        county       date state_name  retail_and_recreation_mobility  \
# 0        1001 2020-04-10    Alabama                             -30
# 1        1001 2020-04-11    Alabama                             -37
# 2        1001 2020-04-12    Alabama                             -55
# 3        1001 2020-04-13    Alabama                             -22
# 4        1001 2020-04-14    Alabama                             -23
# ...       ...        ...        ...                             ...
# 14626   55141 2020-04-19  Wisconsin                             -19
# 14627   55141 2020-04-20  Wisconsin                             -29
# 14628   55141 2020-04-21  Wisconsin                             -31
# 14629   55141 2020-04-22  Wisconsin                             -32
# 14630   55141 2020-04-23  Wisconsin                             -30
#
#        grocery_and_pharmacy_mobility  parks_mobility  transit_mobility  \
# 0                                 12               0                 0
# ...

# %%
## get dates 7 days before/after April 17th (treatment date) and create new variable for time 
df = df[(df.date >= '2020-04-10') & (df.date < '2020-04-24')]

# %%
df
# Out:
#        county       date state_name  retail_and_recreation_mobility  \
# 0        1001 2020-04-10    Alabama                             -30
# 1        1001 2020-04-11    Alabama                             -37
# 2        1001 2020-04-12    Alabama                             -55
# 3        1001 2020-04-13    Alabama                             -22
# 4        1001 2020-04-14    Alabama                             -23
# ...       ...        ...        ...                             ...
# 14626   55141 2020-04-19  Wisconsin                             -19
# 14627   55141 2020-04-20  Wisconsin                             -29
# 14628   55141 2020-04-21  Wisconsin                             -31
# 14629   55141 2020-04-22  Wisconsin                             -32
# 14630   55141 2020-04-23  Wisconsin                             -30
#
#        grocery_and_pharmacy_mobility  parks_mobility  transit_mobility  \
# 0                                 12               0                 0
# ...

# %%
df.to_csv('../data/google_mobility_data.csv', index=False)

# %%
import pandas as pd 
new = pd.read_csv('../data/us_mobility.csv')

new.head()
# Out:
#      state          county        date  \
# 0  Alabama  Autauga County  2020-04-10
# 1  Alabama  Autauga County  2020-04-11
# 2  Alabama  Autauga County  2020-04-12
# 3  Alabama  Autauga County  2020-04-13
# 4  Alabama  Autauga County  2020-04-14
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                              -30.0
# 1                                              -37.0
# 2                                              -55.0
# 3                                              -22.0
# 4                                              -23.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               12.0
# 1                                               16.0
# 2                                              -51.0
# 3                                               -3.0
# 4                                                0.0
#
#    parks_percent_change_from_baseline  \
# ...
